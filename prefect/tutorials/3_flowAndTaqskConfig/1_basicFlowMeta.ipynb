# %%
# from https://docs.prefect.io/tutorials/flow-task-config/

from prefect import flow, task

@task(name="My Example Task", 
      description="An example task for a tutorial.")
def my_task():
    pass
@flow
def my_flow():
    my_task()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/paulayling/Documents/dev/GFPlayground/prefect/tutorials/flowAndTaqskConfig/1_basicFlowConfig.ipynb Cell 1 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/paulayling/Documents/dev/GFPlayground/prefect/tutorials/flowAndTaqskConfig/1_basicFlowConfig.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> # from https://docs.prefect.io/tutorials/flow-task-config/
# ----> <a href='vscode-notebook-cell:/home/paulayling/Documents/dev/GFPlayground/prefect/tutorials/flowAndTaqskConfig/1_basicFlowConfig.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from prefect import flow, task
#       <a href='vscode-notebook-cell:/home/paulayling/Documents/dev/GFPlayground/prefect/tutorials/flowAndTaqskConfig/1_basicFlowConfig.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> @task(name="My Example Task",
# ...
