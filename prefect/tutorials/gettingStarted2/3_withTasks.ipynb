# %%
import random
from prefect import flow, task    # NEW **** 

@task   # NEW ****
def call_unreliable_api():
    choices = [{"data": 42}, "failure"]
    res = random.choice(choices)
    if res == "failure":
        raise Exception("Our unreliable service failed")
    else:
        return res

@task   # NEW ****
def augment_data(data: dict, msg: str):
    data["message"] = msg
    return data

@task   # NEW ****
def write_results_to_database(data: dict):
    print(f"Wrote {data} to database successfully!")
    return "Success!"

@flow 
def pipeline3(msg: str):
    api_result = call_unreliable_api()
    augmented_data = augment_data(data=api_result, msg=msg)
    write_results_to_database(augmented_data)

# %%
pipeline3("We're using flows and tasks now!")
# Out:
# 09:58:01.734 | INFO    | prefect.engine - Created flow run 'skilled-bandicoot' for flow 'pipeline3'
# 09:58:02.020 | INFO    | Flow run 'skilled-bandicoot' - Created task run 'call_unreliable_api-466f2784-0' for task 'call_unreliable_api'
# 09:58:02.021 | INFO    | Flow run 'skilled-bandicoot' - Executing 'call_unreliable_api-466f2784-0' immediately...
# 09:58:02.074 | ERROR   | Task run 'call_unreliable_api-466f2784-0' - Encountered exception during execution:
# Traceback (most recent call last):
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py", line 1069, in orchestrate_task_run
#     result = await run_sync(task.fn, *args, **kwargs)
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\utilities\asyncutils.py", line 56, in run_sync_in_worker_thread
#     return await anyio.to_thread.run_sync(call, cancellable=True)
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\PaulAyling\AppData\Local\Temp\ipykernel_32792\2871783940.py", line 9, in call_unreliable_api
#     raise Exception("Our unreliable service failed")
# Exception: Our unreliable service failed
# 09:58:02.169 | ERROR   | Task run 'call_unreliable_api-466f2784-0' - Finished in state Failed('Task run encountered an exception.')
# 09:58:02.171 | ERROR   | Flow run 'skilled-bandicoot' - Encountered exception during execution:
# Traceback (most recent call last):
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py", line 566, in orchestrate_flow_run
#     result = await run_sync(flow_call)
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\utilities\asyncutils.py", line 56, in run_sync_in_worker_thread
#     return await anyio.to_thread.run_sync(call, cancellable=True)
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\PaulAyling\AppData\Local\Temp\ipykernel_32792\2871783940.py", line 25, in pipeline3
#     api_result = call_unreliable_api()
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\tasks.py", line 294, in __call__
#     return enter_task_run_engine(
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py", line 705, in enter_task_run_engine
#     return run_async_from_worker_thread(begin_run)
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\utilities\asyncutils.py", line 136, in run_async_from_worker_thread
#     return anyio.from_thread.run(call)
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\from_thread.py", line 49, in run
#     return asynclib.run_async_from_thread(func, *args)
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 970, in run_async_from_thread
#     return f.result()
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py", line 458, in result
#     return self.__get_result()
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py", line 403, in __get_result
#     raise self._exception
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py", line 822, in create_task_run_then_submit
#     return await future._result()
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\futures.py", line 227, in _result
#     return final_state.result(raise_on_failure=raise_on_failure)
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\orion\schemas\states.py", line 145, in result
#     raise data
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py", line 1069, in orchestrate_task_run
#     result = await run_sync(task.fn, *args, **kwargs)
#   File "c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\utilities\asyncutils.py", line 56, in run_sync_in_worker_thread
#     return await anyio.to_thread.run_sync(call, cancellable=True)
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\PaulAyling\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\PaulAyling\AppData\Local\Temp\ipykernel_32792\2871783940.py", line 9, in call_unreliable_api
#     raise Exception("Our unreliable service failed")
# Exception: Our unreliable service failed
# 09:58:02.273 | ERROR   | Flow run 'skilled-bandicoot' - Finished in state Failed('Flow run encountered an exception.')
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\PaulAyling\Documents\BACKEND\code\GFplayground\prefect\tutorials\gettingStarted2\3_withTasks.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> pipeline3("We're using flows and tasks now!")
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\flows.py:384, in Flow.__call__(self, return_state, *args, **kwargs)
#     380 parameters = get_call_parameters(self.fn, args, kwargs)
#     382 return_type = "state" if return_state else "result"
# --> 384 return enter_flow_run_engine_from_flow_call(
#     385     self, parameters, return_type=return_type
#     386 )
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py:149, in enter_flow_run_engine_from_flow_call(flow, parameters, return_type)
#     145 if in_async_main_thread():
#     146     # An event loop is already running and we must create a blocking portal to
#     147     # run async code from this synchronous context
#     148     with start_blocking_portal() as portal:
# --> 149         return portal.call(begin_run)
#     150 else:
#     151     # An event loop is not running so we will create one
#     152     return anyio.run(begin_run)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\from_thread.py:283, in BlockingPortal.call(self, func, *args)
#     268 def call(
#     269     self,
#     270     func: Callable[..., Union[Coroutine[Any, Any, T_Retval], T_Retval]],
#     271     *args: object
#     272 ) -> T_Retval:
#     273     """
#     274     Call the given function in the event loop thread.
#     275
#    (...)
#     281
#     282     """
# --> 283     return cast(T_Retval, self.start_task_soon(func, *args).result())
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\from_thread.py:219, in BlockingPortal._call_func(self, func, args, kwargs, future)
#     216             else:
#     217                 future.add_done_callback(callback)
# --> 219             retval = await retval
#     220 except self._cancelled_exc_class:
#     221     future.cancel()
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\client.py:105, in inject_client.<locals>.with_injected_client(*args, **kwargs)
#     103 async with client_context as client:
#     104     kwargs.setdefault("client", client)
# --> 105     return await fn(*args, **kwargs)
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py:228, in create_then_begin_flow_run(flow, parameters, return_type, client)
#     226     return state
#     227 elif return_type == "result":
# --> 228     return state.result()
#     229 else:
#     230     raise ValueError(f"Invalid return type for flow engine {return_type!r}.")
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\orion\schemas\states.py:145, in State.result(self, raise_on_failure)
#     143 if (self.is_failed() or self.is_crashed()) and raise_on_failure:
#     144     if isinstance(data, Exception):
# --> 145         raise data
#     146     elif isinstance(data, BaseException):
#     147         warnings.warn(
#     148             f"State result is a {type(data).__name__!r} type and is not safe "
#     149             "to re-raise, it will be returned instead."
#     150         )
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py:566, in orchestrate_flow_run(flow, flow_run, parameters, interruptible, client, partial_flow_run_context)
#     560             else:
#     561                 run_sync = (
#     562                     run_sync_in_interruptible_worker_thread
#     563                     if interruptible or timeout_scope
#     564                     else run_sync_in_worker_thread
#     565                 )
# --> 566                 result = await run_sync(flow_call)
#     568         waited_for_task_runs = await wait_for_task_runs_and_report_crashes(
#     569             flow_run_context.task_run_futures, client=client
#     570         )
#     572 except Exception as exc:
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\utilities\asyncutils.py:56, in run_sync_in_worker_thread(__fn, *args, **kwargs)
#      45 """
#      46 Runs a sync function in a new worker thread so that the main thread's event loop
#      47 is not blocked
#    (...)
#      53 thread may continue running — the outcome will just be ignored.
#      54 """
#      55 call = partial(__fn, *args, **kwargs)
# ---> 56 return await anyio.to_thread.run_sync(call, cancellable=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py:31, in run_sync(func, cancellable, limiter, *args)
#      10 async def run_sync(
#      11     func: Callable[..., T_Retval],
#      12     *args: object,
#      13     cancellable: bool = False,
#      14     limiter: Optional[CapacityLimiter] = None
#      15 ) -> T_Retval:
#      16     """
#      17     Call the given function with the given arguments in a worker thread.
#      18
#    (...)
#      29
#      30     """
# ---> 31     return await get_asynclib().run_sync_in_worker_thread(
#      32         func, *args, cancellable=cancellable, limiter=limiter
#      33     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py:937, in run_sync_in_worker_thread(func, cancellable, limiter, *args)
#     935 context.run(sniffio.current_async_library_cvar.set, None)
#     936 worker.queue.put_nowait((context, func, args, future))
# --> 937 return await future
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py:867, in WorkerThread.run(self)
#     865 exception: Optional[BaseException] = None
#     866 try:
# --> 867     result = context.run(func, *args)
#     868 except BaseException as exc:
#     869     exception = exc
#
# c:\Users\PaulAyling\Documents\BACKEND\code\GFplayground\prefect\tutorials\gettingStarted2\3_withTasks.ipynb Cell 2 in pipeline3(msg)
#      <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a> @flow
#      <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=23'>24</a> def pipeline3(msg: str):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=24'>25</a>     api_result = call_unreliable_api()
#      <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=25'>26</a>     augmented_data = augment_data(data=api_result, msg=msg)
#      <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=26'>27</a>     write_results_to_database(augmented_data)
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\tasks.py:294, in Task.__call__(self, return_state, wait_for, *args, **kwargs)
#     290 parameters = get_call_parameters(self.fn, args, kwargs)
#     292 return_type = "state" if return_state else "result"
# --> 294 return enter_task_run_engine(
#     295     self,
#     296     parameters=parameters,
#     297     wait_for=wait_for,
#     298     task_runner=SequentialTaskRunner(),
#     299     return_type=return_type,
#     300     mapped=False,
#     301 )
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py:705, in enter_task_run_engine(task, parameters, wait_for, return_type, task_runner, mapped)
#     703 # Async or sync task run in sync flow run
#     704 elif not flow_run_context.flow.isasync:
# --> 705     return run_async_from_worker_thread(begin_run)
#     707 # Sync task run in async flow run
#     708 else:
#     709     # Call out to the sync portal since we are not in a worker thread
#     710     return flow_run_context.sync_portal.call(begin_run)
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\utilities\asyncutils.py:136, in run_async_from_worker_thread(__fn, *args, **kwargs)
#     131 """
#     132 Runs an async function in the main thread's event loop, blocking the worker
#     133 thread until completion
#     134 """
#     135 call = partial(__fn, *args, **kwargs)
# --> 136 return anyio.from_thread.run(call)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\from_thread.py:49, in run(func, *args)
#      46 except AttributeError:
#      47     raise RuntimeError("This function can only be run from an AnyIO worker thread")
# ---> 49 return asynclib.run_async_from_thread(func, *args)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py:970, in run_async_from_thread(func, *args)
#     964 def run_async_from_thread(
#     965     func: Callable[..., Coroutine[Any, Any, T_Retval]], *args: object
#     966 ) -> T_Retval:
#     967     f: concurrent.futures.Future[T_Retval] = asyncio.run_coroutine_threadsafe(
#     968         func(*args), threadlocals.loop
#     969     )
# --> 970     return f.result()
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py:822, in create_task_run_then_submit(task, flow_run_context, parameters, wait_for, return_type, task_runner)
#     820     return await future._wait()
#     821 elif return_type == "result":
# --> 822     return await future._result()
#     823 else:
#     824     raise ValueError(f"Invalid return type for task engine {return_type!r}.")
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\futures.py:227, in PrefectFuture._result(self, timeout, raise_on_failure)
#     225 if not final_state:
#     226     raise TimeoutError("Call timed out before task finished.")
# --> 227 return final_state.result(raise_on_failure=raise_on_failure)
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\orion\schemas\states.py:145, in State.result(self, raise_on_failure)
#     143 if (self.is_failed() or self.is_crashed()) and raise_on_failure:
#     144     if isinstance(data, Exception):
# --> 145         raise data
#     146     elif isinstance(data, BaseException):
#     147         warnings.warn(
#     148             f"State result is a {type(data).__name__!r} type and is not safe "
#     149             "to re-raise, it will be returned instead."
#     150         )
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\engine.py:1069, in orchestrate_task_run(task, task_run, parameters, wait_for, result_filesystem, interruptible, client)
#    1063         else:
#    1064             run_sync = (
#    1065                 run_sync_in_interruptible_worker_thread
#    1066                 if interruptible
#    1067                 else run_sync_in_worker_thread
#    1068             )
# -> 1069             result = await run_sync(task.fn, *args, **kwargs)
#    1071 except Exception as exc:
#    1072     logger.error(
#    1073         f"Encountered exception during execution:",
#    1074         exc_info=True,
#    1075     )
#
# File c:\Users\PaulAyling\AppData\Local\Programs\Python\Python310\lib\site-packages\prefect\utilities\asyncutils.py:56, in run_sync_in_worker_thread(__fn, *args, **kwargs)
#      45 """
#      46 Runs a sync function in a new worker thread so that the main thread's event loop
#      47 is not blocked
#    (...)
#      53 thread may continue running — the outcome will just be ignored.
#      54 """
#      55 call = partial(__fn, *args, **kwargs)
# ---> 56 return await anyio.to_thread.run_sync(call, cancellable=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py:31, in run_sync(func, cancellable, limiter, *args)
#      10 async def run_sync(
#      11     func: Callable[..., T_Retval],
#      12     *args: object,
#      13     cancellable: bool = False,
#      14     limiter: Optional[CapacityLimiter] = None
#      15 ) -> T_Retval:
#      16     """
#      17     Call the given function with the given arguments in a worker thread.
#      18
#    (...)
#      29
#      30     """
# ---> 31     return await get_asynclib().run_sync_in_worker_thread(
#      32         func, *args, cancellable=cancellable, limiter=limiter
#      33     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py:937, in run_sync_in_worker_thread(func, cancellable, limiter, *args)
#     935 context.run(sniffio.current_async_library_cvar.set, None)
#     936 worker.queue.put_nowait((context, func, args, future))
# --> 937 return await future
#
# File ~\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py:867, in WorkerThread.run(self)
#     865 exception: Optional[BaseException] = None
#     866 try:
# --> 867     result = context.run(func, *args)
#     868 except BaseException as exc:
#     869     exception = exc
#
# c:\Users\PaulAyling\Documents\BACKEND\code\GFplayground\prefect\tutorials\gettingStarted2\3_withTasks.ipynb Cell 2 in call_unreliable_api()
#       <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> res = random.choice(choices)
#       <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> if res == "failure":
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>     raise Exception("Our unreliable service failed")
#      <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> else:
#      <a href='vscode-notebook-cell:/c%3A/Users/PaulAyling/Documents/BACKEND/code/GFplayground/prefect/tutorials/gettingStarted2/3_withTasks.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>     return res
#
# Exception: Our unreliable service failed
